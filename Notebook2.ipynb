# %%
import pandas as ps

# %% [markdown]
# 2 .Total working days for each agents
# 3. Total query that you hvae taken
# 11 . list of all agents name
# 13 . Total contributation hour for each and every agents weekly basis

# %% [markdown]
# Thia notebook conisist task of 2,3,13,11

# %%
df1 = ps.read_excel(r'C:\Users\dchakrab.COMPUTACENTER\Downloads\Agent_Login_Report (4).xls')

# %%
df1
# Out:
#      Agent Login Report          Unnamed: 1 Unnamed: 2   Unnamed: 3  \
# 0                   NaN                 NaN        NaN          NaN
# 1                 SL No               Agent       Date   Login Time
# 2                     1  Shivananda Sonwane  30-Jul-22  03:35:29 PM
# 3                     2      Khushboo Priya  30-Jul-22  03:06:59 PM
# 4                     3       Nandani Gupta  30-Jul-22  03:04:24 PM
# ...                 ...                 ...        ...          ...
# 997                 996        Manjunatha A  20-Jul-22  09:03:51 AM
# 998                 997            Bharath   20-Jul-22  09:00:49 AM
# 999                 998      Khushboo Priya  20-Jul-22  08:59:20 AM
# 1000                999        Nishtha Jain  20-Jul-22  08:43:55 AM
# 1001               1000              Tarun   01-Jul-22  01:52:47 AM
#
#        Unnamed: 4 Unnamed: 5
# 0             NaN        NaN
# 1     Logout Time   Duration
# 2     05:39:39 PM   02:04:10
# 3     03:07:16 PM   00:00:17
# ...

# %%
df1.drop(0, inplace =True)

# %%
df1
# Out:
#      Agent Login Report          Unnamed: 1 Unnamed: 2   Unnamed: 3  \
# 1                 SL No               Agent       Date   Login Time
# 2                     1  Shivananda Sonwane  30-Jul-22  03:35:29 PM
# 3                     2      Khushboo Priya  30-Jul-22  03:06:59 PM
# 4                     3       Nandani Gupta  30-Jul-22  03:04:24 PM
# 5                     4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM
# ...                 ...                 ...        ...          ...
# 997                 996        Manjunatha A  20-Jul-22  09:03:51 AM
# 998                 997            Bharath   20-Jul-22  09:00:49 AM
# 999                 998      Khushboo Priya  20-Jul-22  08:59:20 AM
# 1000                999        Nishtha Jain  20-Jul-22  08:43:55 AM
# 1001               1000              Tarun   01-Jul-22  01:52:47 AM
#
#        Unnamed: 4 Unnamed: 5
# 1     Logout Time   Duration
# 2     05:39:39 PM   02:04:10
# 3     03:07:16 PM   00:00:17
# 4     05:31:07 PM   02:26:42
# ...

# %%
new_header1 = df1.iloc[0]

# %%
df1.columns = new_header1

# %%
df1
# Out:
# 1     SL No               Agent       Date   Login Time  Logout Time  \
# 1     SL No               Agent       Date   Login Time  Logout Time
# 2         1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM
# 3         2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM
# 4         3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM
# 5         4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM
# ...     ...                 ...        ...          ...          ...
# 997     996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM
# 998     997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM
# 999     998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM
# 1000    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM
# 1001   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM
#
# 1      Duration
# 1      Duration
# 2      02:04:10
# 3      00:00:17
# 4      02:26:42
# 5      00:45:06
# ...         ...
# ...

# %%
df1.drop(1, inplace = True)

# %%
df1
# Out:
# 1    SL No               Agent       Date   Login Time  Logout Time   Duration
# 2        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 3        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 4        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 5        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 6        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ...    ...                 ...        ...          ...          ...        ...
# 997    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 998    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 999    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 1000   999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 1001  1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 6 columns]

# %%
df1.dtypes
# Out:
# 1
# SL No          object
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
df1['converted_duration'] = ps.to_datetime(df1['Duration']).dt.time
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:536, in pandas._libs.tslib.array_to_datetime()
#
# ...

# %%
df1.Duration.str.replace('24',"23")
# Out:
# 2        02:04:10
# 3        00:00:17
# 4        02:26:42
# 5        00:45:06
# 6        01:08:36
#           ...
# 997      05:58:37
# 998      06:00:43
# 999      05:27:34
# 1000     05:16:38
# 1001    514:08:20
# Name: Duration, Length: 1000, dtype: object

# %%
df1['Duration']=df1.Duration.str.replace('514',"23")

# %%
df1['Duration']=df1.Duration.str.replace('24','23')

# %%
df1
# Out:
# 1    SL No               Agent       Date   Login Time  Logout Time  Duration
# 2        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM  02:04:10
# 3        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM  00:00:17
# 4        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM  02:26:42
# 5        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM  00:45:06
# 6        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM  01:08:36
# ...    ...                 ...        ...          ...          ...       ...
# 997    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM  05:58:37
# 998    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM  06:00:43
# 999    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM  05:27:34
# 1000   999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM  05:16:38
# 1001  1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  23:08:20
#
# [1000 rows x 6 columns]

# %%
df1
# Out:
# 1    SL No               Agent       Date   Login Time  Logout Time  Duration  \
# 2        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM  02:04:10
# 3        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM  00:00:17
# 4        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM  02:26:42
# 5        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM  00:45:06
# 6        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM  01:08:36
# ...    ...                 ...        ...          ...          ...       ...
# 997    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM  05:58:37
# 998    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM  06:00:43
# 999    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM  05:27:34
# 1000   999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM  05:16:38
# 1001  1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  23:08:20
#
# 1    converted_duration
# ...

# %%
df1['converted_duration'] = ps.to_timedelta(df1['Duration'])

# %%
df1.head()
# Out:
# 1 SL No               Agent       Date   Login Time  Logout Time  Duration  \
# 2     1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM  02:04:10
# 3     2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM  00:00:17
# 4     3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM  02:26:42
# 5     4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM  00:45:06
# 6     5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM  01:08:36
#
# 1 converted_duration
# 2    0 days 02:04:10
# 3    0 days 00:00:17
# 4    0 days 02:26:42
# 5    0 days 00:45:06
# 6    0 days 01:08:36

# %%
df1.groupby('Agent')['converted_duration'].sum()
# Out:
# Agent
# Aditya Shinde            0 days 00:02:10
# Aditya_iot               0 days 15:43:52
# Amersh                   0 days 03:03:50
# Ameya Jain               1 days 18:04:31
# Ankitjha                 0 days 02:16:00
# Anurag Tiwari            0 days 02:46:44
# Aravind                  1 days 00:17:57
# Ayushi Mishra            1 days 14:07:18
# Bharath                  2 days 00:04:36
# Boktiar Ahmed Bappy      1 days 16:16:06
# Chaitra K Hiremath       1 days 10:19:32
# Deepranjan Gupta         4 days 10:16:30
# Dibyanshu                2 days 04:34:43
# Harikrishnan Shaji       2 days 05:42:52
# Hrisikesh Neogi          2 days 09:33:07
# Hyder Abbas              0 days 00:23:17
# Ineuron Intelligence     0 days 01:26:55
# Ishawant Kumar           2 days 03:46:43
# Jawala Prakash           1 days 22:24:08
# Jaydeep Dixit            2 days 10:50:26
# Khushboo Priya           1 days 19:33:31
# Madhulika G              1 days 22:03:37
# Mahesh Sarade            1 days 18:53:19
# ...

# %% [markdown]
# Total number of working hours for each agent for the month

# %%
Total query that you hvae taken
# Out:
#   Input In [52]
#     Total query that you hvae taken
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# Total query that you hvae taken

# %%
# Out:
# C:\Users\dchakrab.COMPUTACENTER\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# Out:
#      Agent Performance Report  Unnamed: 1          Unnamed: 2   Unnamed: 3  \
# 0                       SL No        Date          Agent Name  Total Chats
# 1                           1  2022-07-30        Prerna Singh           11
# 2                           2  2022-07-30       Nandani Gupta           11
# 3                           3  2022-07-30          Ameya Jain           14
# 4                           4  2022-07-30       Mahesh Sarade           14
# ...                       ...         ...                 ...          ...
# 2156                     2156  2022-07-01   Sowmiya Sivakumar            0
# 2157                     2157  2022-07-01             Nitin M            0
# 2158                     2158  2022-07-01              Vivek             0
# 2159                     2159  2022-07-01       Ayushi Mishra            0
# 2160                     2160  2022-07-01  Chaitra K Hiremath            0
#
# ...

# %% [markdown]
#  list of all agents name

# %%
ps.unique(df1['Agent'])
# Out:
# array(['Shivananda Sonwane', 'Khushboo Priya', 'Nandani Gupta',
#        'Hrisikesh Neogi', 'Mukesh ', 'Sowmiya Sivakumar', 'Manjunatha A',
#        'Harikrishnan Shaji', 'Suraj S Bilgi', 'Shivan K', 'Anurag Tiwari',
#        'Ishawant Kumar', 'Shubham Sharma', 'Prerna Singh', 'Nishtha Jain',
#        'Prateek _iot ', 'Mithun S', 'Madhulika G', 'Boktiar Ahmed Bappy',
#        'Jawala Prakash', 'Dibyanshu ', 'Deepranjan Gupta',
#        'Jaydeep Dixit', 'Ayushi Mishra', 'Mahesh Sarade', 'Muskan Garg',
#        'Chaitra K Hiremath', 'Shiva Srivastava', 'Aditya_iot ',
#        'Prabir Kumar Satapathy', 'Sanjeev Kumar', 'Zeeshan ',
#        'Rishav Dash', 'Wasim ', 'Bharath ', 'Ameya Jain',
#        'Saikumarreddy N', 'Aravind ', 'Amersh ', 'Sudhanshu Kumar',
#        'Ankitjha ', 'Maitry ', 'Aditya Shinde', 'Hyder Abbas', 'Swati ',
#        'Saurabh Shukla', 'Nitin M', 'Ineuron Intelligence ', 'Tarun '],
#       dtype=object)

# %%
len(ps.unique(df1['Agent']))
# Out:
# 49

# %% [markdown]
# Total contributation hour for each and every agents weekly basis

# %%
df1
# Out:
# 1    SL No               Agent       Date   Login Time  Logout Time  Duration  \
# 2        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM  02:04:10
# 3        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM  00:00:17
# 4        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM  02:26:42
# 5        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM  00:45:06
# 6        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM  01:08:36
# ...    ...                 ...        ...          ...          ...       ...
# 997    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM  05:58:37
# 998    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM  06:00:43
# 999    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM  05:27:34
# 1000   999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM  05:16:38
# 1001  1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  23:08:20
#
# 1    converted_duration
# ...

# %%
df1['converted_date'] = ps.to_datetime(df1['Date'])

# %%
df1['week']=df1['converted_date'].dt.week
# Out:
# C:\Users\dchakrab.COMPUTACENTER\AppData\Local\Temp\ipykernel_23932\737109390.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df1['week']=df1['converted_date'].dt.week

# %%
df1
# Out:
# 1    SL No               Agent       Date   Login Time  Logout Time  Duration  \
# 2        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM  02:04:10
# 3        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM  00:00:17
# 4        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM  02:26:42
# 5        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM  00:45:06
# 6        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM  01:08:36
# ...    ...                 ...        ...          ...          ...       ...
# 997    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM  05:58:37
# 998    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM  06:00:43
# 999    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM  05:27:34
# 1000   999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM  05:16:38
# 1001  1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  23:08:20
#
# ...

# %%
df1.groupby(['Agent','week'])['converted_duration'].sum()
# Out:
# Agent          week
# Aditya Shinde  30     0 days 00:02:10
# Aditya_iot     29     0 days 06:05:43
#                30     0 days 09:38:09
# Amersh         30     0 days 03:03:50
# Ameya Jain     29     1 days 00:04:58
#                             ...
# Tarun          26     0 days 23:08:20
# Wasim          29     0 days 19:37:32
#                30     1 days 04:32:13
# Zeeshan        29     1 days 00:25:39
#                30     1 days 00:39:40
# Name: converted_duration, Length: 89, dtype: timedelta64[ns]

# %%
df10 = df1.groupby(['Agent','week'])['converted_duration'].sum()

# %%
df10
# Out:
# Agent          week
# Aditya Shinde  30     0 days 00:02:10
# Aditya_iot     29     0 days 06:05:43
#                30     0 days 09:38:09
# Amersh         30     0 days 03:03:50
# Ameya Jain     29     1 days 00:04:58
#                             ...
# Tarun          26     0 days 23:08:20
# Wasim          29     0 days 19:37:32
#                30     1 days 04:32:13
# Zeeshan        29     1 days 00:25:39
#                30     1 days 00:39:40
# Name: converted_duration, Length: 89, dtype: timedelta64[ns]

# %%
# Out:
# Agent        week
# Aditya_iot   30     0 days 09:38:09
# Name: converted_duration, dtype: timedelta64[ns]
